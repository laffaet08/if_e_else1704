# %% [markdown]
# <a href="https://colab.research.google.com/github/laffaet08/if_e_else1704/blob/main/aula17_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input("Digite sua idade: "))
if idade >= 18:
  print("voce é maior de idade")
else:
  print("voce é menor de idade")
# Out:
# Digite sua idade: 23
# voce é maior de idade

# %%
idade = 14
if idade < 16:
  print("voce é menor de idade")
elif idade >= 16 and idade < 18:
  print("voto opcional")
elif idade >= 18:
  print("voto obrigatorio")
else:
  print("nenhuma das opcoes")
# Out:
# voce é menor de idade
